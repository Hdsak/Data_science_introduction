# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_csv("https://stepik.org/media/attachments/course/4852/income.csv")
df.head()
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
df.plot(kind='line')

# %%
sns.lineplot(x=df.index, y=df.income)

# %%
df['income'].plot()

# %%
df.income.plot()

# %%
df.plot()

# %%
sns.lineplot(data=df)

# %%
plt.plot(df.index, df.income)

# %%
df_2 = pd.read_csv(r"C:\Users\Hdsak\Downloads\ds.txt", sep=" ")
df_2.head()
sns.lmplot(x='x',y='y',data=df_2)

# %%
sns.scatterplot(df_2.iloc[:, 0], df_2.iloc[:, 1])

# %%
df_3 = pd.read_csv("https://stepik.org/media/attachments/course/4852/genome_matrix.csv", index_col=0)
df_3.head()
heatmap_plot = sns.heatmap(df_3, center=0, cmap='gist_ncar')

# %%
df_4 = pd.read_csv("https://stepik.org/media/attachments/course/4852/dota_hero_stats.csv")
df_4.head()
df_4.roles.hist()
df_4['roles'].str.split(",").str.len().value_counts()
# Out:
# 4    38
# 5    33
# 3    28
# 2     9
# 6     8
# 1     1
# Name: roles, dtype: int64

# %%
df_5 = pd.read_csv("https://stepik.org/media/attachments/course/4852/iris.csv")
df_5= df_5.drop(["Unnamed: 0"],axis=1)
df_5.head()
# Out:
#    sepal length  sepal width  petal length  petal width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
sns.distplot(df_5["sepal length"])

# %%
sns.distplot(df_5["sepal width"])

# %%
sns.distplot(df_5["petal length"])

# %%
sns.distplot(df_5["petal width"])

# %%
for column in df_5:
    sns.distplot(df_5[column], label = column, hist = False)

# %%
sns.violinplot(y=df_5["petal length"])

# %%
sns.pairplot(data=df_5,vars=df_5.columns[:4], hue="species")
